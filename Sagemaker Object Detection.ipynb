# %% [markdown]
# # Download the Data

# %%
# !pip3 install tqdm
# !pip3 install pillow --upgrade
# Out:
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (4.44.1)
# WARNING: You are using pip version 20.0.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/bin/python -m pip install --upgrade pip' command.
# Collecting pillow
#   Downloading Pillow-7.2.0-cp36-cp36m-manylinux1_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 3.2 MB/s eta 0:00:01
# Installing collected packages: pillow
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# Successfully installed pillow-7.2.0
# WARNING: You are using pip version 20.0.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/bin/python -m pip install --upgrade pip' command.

# %%
# %matplotlib inline

import os
import tarfile
import urllib
import shutil
import json
import random
import numpy as np
import boto3
import sagemaker

from tqdm import tqdm
from sagemaker.amazon.amazon_estimator import get_image_uri
from matplotlib import pyplot as plt
from xml.etree import ElementTree as ET
from PIL import Image, ImageDraw, ImageFont

urls = ['http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz',
        'http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz']

def download_and_extract(data_dir, download_dir):
    for url in urls:
        target_file = url.split('/')[-1]
        if target_file not in os.listdir(download_dir):
            print('Downloading', url)
            urllib.request.urlretrieve(url, os.path.join(download_dir, target_file))
            tf = tarfile.open(url.split('/')[-1])
            tf.extractall(data_dir)
        else:
            print('Already downloaded', url)

if not os.path.isdir('data'):
    os.mkdir('data')

download_and_extract('data', '.')
# Out:
# Already downloaded http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Already downloaded http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz

# %% [markdown]
# # Extracting Annotations from XML Format

# %%
xml_dir = 'data/annotations/xmls/'
xml_files = [os.path.join(xml_dir, x) for x in os.listdir(xml_dir) if x[-3:] == 'xml']
xml_files[0]
# Out:
# 'data/annotations/xmls/Sphynx_206.xml'

# %%
classes = ['cat', 'dog']
categories = [
    {
        'class_id': 0,
        'name': 'cat'
    },
    {
        'class_id': 1,
        'name': 'dog'
    }
]

# %%
def extract_annotation(xml_file_path):
    
    tree = ET.parse(xml_file_path)
    root = tree.getroot()
    annotation = {}
    
    annotation['file'] = root.find('filename').text
    annotation['categories'] = categories
    
    size = root.find('size')
    
    annotation['image_size'] = [{
        'width': int(size.find('width').text),
        'height': int(size.find('height').text),
        'depth': int(size.find('depth').text)
    }]
    
    annotation['annotations'] = []
    
    for item in root.iter('object'):
        class_id = classes.index(item.find('name').text)
        ymin, xmin, ymax, xmax = None, None, None, None
        
        for box in item.findall('bndbox'):
            xmin = int(box.find("xmin").text)
            ymin = int(box.find("ymin").text)
            xmax = int(box.find("xmax").text)
            ymax = int(box.find("ymax").text)
        
            if all([xmin, ymin, xmax, ymax]) is not None:
                 annotation['annotations'].append({
                     'class_id': class_id,
                     'left': xmin,
                     'top': ymin,
                     'width': xmax - xmin,
                     'height': ymax - ymin
                 })
    return annotation

# %%
extract_annotation(xml_files[0])
# Out:
# {'file': 'Sphynx_206.jpg',
#  'categories': [{'class_id': 0, 'name': 'cat'},
#   {'class_id': 1, 'name': 'dog'}],
#  'image_size': [{'width': 345, 'height': 500, 'depth': 3}],
#  'annotations': [{'class_id': 0,
#    'left': 85,
#    'top': 19,
#    'width': 260,
#    'height': 280}]}

# %% [markdown]
# # Visualize Data

# %%
def plot_example(plt, annot, image_file_path, rows, cols, index):
    img = Image.open(image_file_path)
    draw = ImageDraw.Draw(img)
    font = ImageFont.truetype('/usr/share/fonts/dejavu/DejaVuSansCondensed-Bold.ttf', 25)
    
    for a in annot['annotations']:
        box = [
            int(a['left']), int(a['top']),
            int(a['left']) + int(a['width']),
            int(a['top']) + int(a['height'])
        ]
        draw.rectangle(box, outline='red', width=4)
        draw.text((box[0], box[1]), classes[int(a['class_id'])], font=font)
    plt.subplot(rows, cols, index + 1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img)
    return plt

def show_random_annotations(plt):
    plt.figure(figsize=(16, 16))
    for i in range(0, 9):
        index = random.randint(0, len(xml_files) - 1)
        
        annot = extract_annotation(xml_files[index])
        image_file_path = os.path.join('data/images/', annot['file'])

        plt = plot_example(plt, annot, image_file_path, 3, 3, i)
    plt.show()

# %%
show_random_annotations(plt)

# %% [markdown]
# # SageMaker Setup

# %%
role = sagemaker.get_execution_role()

bucket_name = 'petsdata26'

training_image = get_image_uri(boto3.Session().region_name, 'object-detection', repo_version='latest')
print(training_image)
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 825641698319.dkr.ecr.us-east-2.amazonaws.com/object-detection:latest

# %%
folders = ['train', 'train_annotation', 'validation', 'validation_annotation']

for folder in folders:
    if os.path.isdir(folder):
        shutil.rmtree(folder)
    os.mkdir(folder)

# %% [markdown]
# # Preparing Data for SageMaker

# %%
print('Total examples:', len(xml_files))
# Out:
# Total examples: 3686

# %%
for xml_file in tqdm(xml_files):
    target_set = 'train' if random.randint(0, 99) < 75 else 'validation'
    annot = extract_annotation(xml_file)
    image_file_path = os.path.join('data/images/', annot['file'])
    image_target_path = os.path.join(target_set, annot['file'])
    shutil.copy(image_file_path, image_target_path)
    json_file_path = os.path.join(target_set + '_annotation', annot['file'][:-3] + 'json')
    with open(json_file_path, 'w') as f:
        json.dump(annot, f)
# Out:
# 100%|██████████| 3686/3686 [00:27<00:00, 133.94it/s]

# %%
train_images = os.listdir('train')
train_annots = os.listdir('train_annotation')

# %%
print(len(train_annots), len(train_images))
# Out:
# 2736 2736

# %%
for image in train_images:
    key = image.split('.')[0]
    json_file = key + '.json'
    if json_file not in train_annots:
        print('Not found', json_file)

# %% [markdown]
# # Uploading Data to S3

# %%
sess = sagemaker.Session()

print('Uploading data...')

s3_training_path = sess.upload_data(path='train', bucket=bucket_name, key_prefix='train')
print('Training images uploaded')

s3_validation_path = sess.upload_data(path='validation', bucket=bucket_name, key_prefix='validation')
print('Validation images uploaded')

s3_train_annotation = sess.upload_data(path='train_annotation', bucket=bucket_name, key_prefix='train_annotation')
print('Training annotations uploaded')

s3_validation_annotation = sess.upload_data(path='validation_annotation', bucket=bucket_name, key_prefix='validation_annotation')
print('Validation annotations uploaded')
# Out:
# Uploading data...
# Training images uploaded
# Validation images uploaded
# Training annotations uploaded
# Validation annotations uploaded

# %%
s3_validation_annotation
# Out:
# 's3://petsdata26/validation_annotation'

# %% [markdown]
# # SageMaker Estimator

# %%
model = sagemaker.estimator.Estimator(
    training_image,
    role = role,
    train_instance_type = 'ml.p3.2xlarge',
    train_instance_count = 1,
    train_volume_size = 100,
    train_max_run = 36000,
    input_mode = 'File',
    output_path = 's3://petsdata26/output',
    sagemaker_session = sess)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# # Hyperparameters

# %%
model.set_hyperparameters(
    base_network='resnet-50',
    num_classes=2,
    use_pretrained_model=1,
    mini_batch_size=16,
    epochs=15,
    learning_rate=0.001,
    optimizer='sgd',
    lr_scheduler_step='10',
    lr_scheduler_factor=0.1,
    momentum=0.9,
    weight_decay=0.0005,
    overlap_threshold=0.5,
    nms_threshold=0.45,
    image_shape=512,
    num_training_samples=len(train_annots)
)

# %% [markdown]
# # Data Channels

# %%
from sagemaker.session import s3_input

train_data = s3_input(s3_training_path, distribution = 'FullyReplicated',
                      content_type = 'application/x-image', s3_data_type = 'S3Prefix')

validation_data = s3_input(s3_validation_path, distribution = 'FullyReplicated',
                      content_type = 'application/x-image', s3_data_type = 'S3Prefix')

train_annotation_data = s3_input(s3_train_annotation, distribution = 'FullyReplicated',
                      content_type = 'application/x-image', s3_data_type = 'S3Prefix')

validation_annotation_data = s3_input(s3_validation_annotation, distribution = 'FullyReplicated',
                      content_type = 'application/x-image', s3_data_type = 'S3Prefix')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
data_channels = {
    'train': train_data,
    'validation': validation_data,
    'train_annotation': train_annotation_data,
    'validation_annotation': validation_annotation_data
}

# %%
data_channels
# Out:
# {'train': <sagemaker.inputs.s3_input at 0x7f10fee60a90>,
#  'validation': <sagemaker.inputs.s3_input at 0x7f10fee609e8>,
#  'train_annotation': <sagemaker.inputs.s3_input at 0x7f10fee609b0>,
#  'validation_annotation': <sagemaker.inputs.s3_input at 0x7f10fee60b70>}

# %% [markdown]
# # Model Training

# %%
model.fit(inputs = data_channels, logs = True)
# Out:
# 2020-10-25 01:52:57 Starting - Starting the training job...
# 2020-10-25 01:52:58 Starting - Launching requested ML instances......
# 2020-10-25 01:54:06 Starting - Preparing the instances for training......
# 2020-10-25 01:55:18 Downloading - Downloading input data............
# 2020-10-25 01:57:25 Training - Downloading the training image...
# 2020-10-25 01:57:39 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# [10/25/2020 01:57:44 INFO 139771535177536] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'30', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'32', u'use_pretrained_model': u'0', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'', u'base_network': u'vgg-16', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'300'}
# [10/25/2020 01:57:44 INFO 139771535177536] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'learning_rate': u'0.001', u'epochs': u'15', u'nms_threshold': u'0.45', u'optimizer': u'sgd', u'base_network': u'resnet-50', u'image_shape': u'512', u'lr_scheduler_step': u'10', u'momentum': u'0.9', u'overlap_threshold': u'0.5', u'num_training_samples': u'2736', u'mini_batch_size': u'16', u'weight_decay': u'0.0005', u'use_pretrained_model': u'1', u'num_classes': u'2', u'lr_scheduler_factor': u'0.1'}
# [10/25/2020 01:57:44 INFO 139771535177536] Final configuration: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'15', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'16', u'use_pretrained_model': u'1', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'10', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'2736', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'2', u'base_network': u'resnet-50', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'512'}
# Process 1 is a worker.
# [10/25/2020 01:57:44 INFO 139771535177536] Using default worker.
# [10/25/2020 01:57:44 INFO 139771535177536] Loaded iterator creator application/x-image for content type ('application/x-image', '1.0')
# [10/25/2020 01:57:44 INFO 139771535177536] Loaded iterator creator application/x-recordio for content type ('application/x-recordio', '1.0')
# [10/25/2020 01:57:44 INFO 139771535177536] Loaded iterator creator image/png for content type ('image/png', '1.0')
# [10/25/2020 01:57:44 INFO 139771535177536] Loaded iterator creator image/jpeg for content type ('image/jpeg', '1.0')
# [10/25/2020 01:57:44 INFO 139771535177536] Checkpoint loading and saving are disabled.
# [10/25/2020 01:57:45 INFO 139771535177536] nvidia-smi took: 0.025190114975 secs to identify 1 gpus
# Creating .rec file from /opt/ml/input/data/train/train.lst in /opt/ml/input/data/train
# time: 0.0246148109436  count: 0
# time: 1.23612499237  count: 1000
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# time: 1.29987502098  count: 2000
# time: 1.17140102386  count: 3000
# Creating .rec file from /opt/ml/input/data/validation/val.lst in /opt/ml/input/data/validation
# time: 0.0126659870148  count: 0
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# time: 1.35492300987  count: 1000
# [10/25/2020 01:57:54 INFO 139771535177536] Number of GPUs being used: 1
# [10/25/2020 01:57:54 WARNING 139771535177536] Training images are resized to image shape (3, 512, 512)
# [01:57:54] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, use 7 threads for decoding..
# [01:57:54] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, label padding width: 350
# [10/25/2020 01:57:56 WARNING 139771535177536] Validation images are resized to image shape (3, 512, 512)
# [01:57:56] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, use 7 threads for decoding..
# [01:57:56] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, label padding width: 350
# [10/25/2020 01:58:00 INFO 139771535177536] Number of GPUs being used: 1
# [10/25/2020 01:58:00 INFO 139771535177536] Using [gpu(0)] as training context.
# [10/25/2020 01:58:00 INFO 139771535177536] Number of GPUs being used: 1
# [10/25/2020 01:58:00 INFO 139771535177536] Create Store: device
# [10/25/2020 01:58:00 INFO 139771535177536] Using (gpu(0)) as training context.
# [10/25/2020 01:58:00 INFO 139771535177536] Start training from pretrained model 1.
# [01:58:00] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [01:58:00] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# [10/25/2020 01:58:01 INFO 139771535177536] Loaded pretrained model parameters.
# [10/25/2020 01:58:16 INFO 139771535177536] Creating a new state instance.
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1603591096.186464, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1603591096.186343}
#
# [01:58:16] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [10/25/2020 01:58:53 INFO 139771535177536] Epoch:    0, batches:    100, num_examples:   1600, 42.4 samples/sec, epoch time so far:  0:00:37.767155
# [10/25/2020 01:59:25 INFO 139771535177536] Epoch:    0, batches:    200, num_examples:   3200, 46.5 samples/sec, epoch time so far:  0:01:08.835439
# [10/25/2020 01:59:30 INFO 139771535177536] #quality_metric: host=algo-1, epoch=0, batch=217 train cross_entropy <loss>=(1.0702081674213806)
# [10/25/2020 01:59:30 INFO 139771535177536] #quality_metric: host=algo-1, epoch=0, batch=217 train smooth_l1 <loss>=(0.6330789204039262)
# [10/25/2020 01:59:30 INFO 139771535177536] Round of batches complete
# [10/25/2020 01:59:30 INFO 139771535177536] Updated the metrics
# [10/25/2020 01:59:50 INFO 139771535177536] #quality_metric: host=algo-1, epoch=0, validation mAP <score>=(0.18476137102971063)
# [10/25/2020 01:59:50 INFO 139771535177536] Updating the best model with validation-mAP=0.18476137102971063
# [10/25/2020 01:59:50 INFO 139771535177536] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/25/2020 01:59:50 INFO 139771535177536] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1603591190.557222, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 0}, "StartTime": 1603591096.186853}
#
# [10/25/2020 02:00:23 INFO 139771535177536] Epoch:    1, batches:    100, num_examples:   1600, 49.2 samples/sec, epoch time so far:  0:00:32.520073
# [10/25/2020 02:00:54 INFO 139771535177536] Epoch:    1, batches:    200, num_examples:   3200, 50.1 samples/sec, epoch time so far:  0:01:03.852626
# [10/25/2020 02:00:59 INFO 139771535177536] #quality_metric: host=algo-1, epoch=1, batch=216 train cross_entropy <loss>=(0.7948668960304717)
# [10/25/2020 02:00:59 INFO 139771535177536] #quality_metric: host=algo-1, epoch=1, batch=216 train smooth_l1 <loss>=(0.5605684388073391)
# [10/25/2020 02:00:59 INFO 139771535177536] Round of batches complete
# [10/25/2020 02:00:59 INFO 139771535177536] Updated the metrics
# [10/25/2020 02:01:18 INFO 139771535177536] #quality_metric: host=algo-1, epoch=1, validation mAP <score>=(0.463987667480873)
# [10/25/2020 02:01:18 INFO 139771535177536] Updating the best model with validation-mAP=0.463987667480873
# [10/25/2020 02:01:18 INFO 139771535177536] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/25/2020 02:01:18 INFO 139771535177536] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1603591278.506186, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 1}, "StartTime": 1603591190.55743}
#
# [10/25/2020 02:01:51 INFO 139771535177536] Epoch:    2, batches:    100, num_examples:   1600, 48.9 samples/sec, epoch time so far:  0:00:32.732121
# [10/25/2020 02:02:22 INFO 139771535177536] Epoch:    2, batches:    200, num_examples:   3200, 50.2 samples/sec, epoch time so far:  0:01:03.744910
# [10/25/2020 02:02:27 INFO 139771535177536] #quality_metric: host=algo-1, epoch=2, batch=216 train cross_entropy <loss>=(0.6726886813347698)
# [10/25/2020 02:02:27 INFO 139771535177536] #quality_metric: host=algo-1, epoch=2, batch=216 train smooth_l1 <loss>=(0.4841865227642727)
# [10/25/2020 02:02:27 INFO 139771535177536] Round of batches complete
# [10/25/2020 02:02:27 INFO 139771535177536] Updated the metrics
# [10/25/2020 02:02:47 INFO 139771535177536] #quality_metric: host=algo-1, epoch=2, validation mAP <score>=(0.7840346981033602)
# [10/25/2020 02:02:47 INFO 139771535177536] Updating the best model with validation-mAP=0.7840346981033602
# [10/25/2020 02:02:47 INFO 139771535177536] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/25/2020 02:02:47 INFO 139771535177536] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1603591367.411813, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 2}, "StartTime": 1603591278.506445}
#
# [10/25/2020 02:03:20 INFO 139771535177536] Epoch:    3, batches:    100, num_examples:   1600, 48.6 samples/sec, epoch time so far:  0:00:32.927511
# [10/25/2020 02:03:51 INFO 139771535177536] Epoch:    3, batches:    200, num_examples:   3200, 50.1 samples/sec, epoch time so far:  0:01:03.844398
# [10/25/2020 02:03:56 INFO 139771535177536] #quality_metric: host=algo-1, epoch=3, batch=216 train cross_entropy <loss>=(0.5996022719511516)
# [10/25/2020 02:03:56 INFO 139771535177536] #quality_metric: host=algo-1, epoch=3, batch=216 train smooth_l1 <loss>=(0.38773680356945184)
# [10/25/2020 02:03:56 INFO 139771535177536] Round of batches complete
# [10/25/2020 02:03:56 INFO 139771535177536] Updated the metrics
# [10/25/2020 02:04:17 INFO 139771535177536] #quality_metric: host=algo-1, epoch=3, validation mAP <score>=(0.905692433585078)
# [10/25/2020 02:04:17 INFO 139771535177536] Updating the best model with validation-mAP=0.905692433585078
# [10/25/2020 02:04:17 INFO 139771535177536] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/25/2020 02:04:17 INFO 139771535177536] #progress_metric: host=algo-1, completed 26 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1603591457.515651, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 3}, "StartTime": 1603591367.412103}
#
# [10/25/2020 02:04:50 INFO 139771535177536] Epoch:    4, batches:    100, num_examples:   1600, 48.7 samples/sec, epoch time so far:  0:00:32.822039
# [10/25/2020 02:05:21 INFO 139771535177536] Epoch:    4, batches:    200, num_examples:   3200, 49.8 samples/sec, epoch time so far:  0:01:04.194066
# [10/25/2020 02:05:26 INFO 139771535177536] #quality_metric: host=algo-1, epoch=4, batch=216 train cross_entropy <loss>=(0.5606737773129894)
# [10/25/2020 02:05:26 INFO 139771535177536] #quality_metric: host=algo-1, epoch=4, batch=216 train smooth_l1 <loss>=(0.3238130854952867)
# [10/25/2020 02:05:26 INFO 139771535177536] Round of batches complete
# [10/25/2020 02:05:26 INFO 139771535177536] Updated the metrics
# [10/25/2020 02:05:48 INFO 139771535177536] #quality_metric: host=algo-1, epoch=4, validation mAP <score>=(0.9532664259993847)
# [10/25/2020 02:05:48 INFO 139771535177536] Updating the best model with validation-mAP=0.9532664259993847
# [10/25/2020 02:05:48 INFO 139771535177536] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/25/2020 02:05:48 INFO 139771535177536] #progress_metric: host=algo-1, completed 33 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1603591548.205864, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 4}, "StartTime": 1603591457.515948}
#
# [10/25/2020 02:06:20 INFO 139771535177536] Epoch:    5, batches:    100, num_examples:   1600, 49.1 samples/sec, epoch time so far:  0:00:32.587989
# [10/25/2020 02:06:51 INFO 139771535177536] Epoch:    5, batches:    200, num_examples:   3200, 50.3 samples/sec, epoch time so far:  0:01:03.651900
# [10/25/2020 02:06:57 INFO 139771535177536] #quality_metric: host=algo-1, epoch=5, batch=217 train cross_entropy <loss>=(0.5296759442660077)
# [10/25/2020 02:06:57 INFO 139771535177536] #quality_metric: host=algo-1, epoch=5, batch=217 train smooth_l1 <loss>=(0.28068604727126845)
# [10/25/2020 02:06:57 INFO 139771535177536] Round of batches complete
# [10/25/2020 02:06:57 INFO 139771535177536] Updated the metrics
# [10/25/2020 02:07:18 INFO 139771535177536] #quality_metric: host=algo-1, epoch=5, validation mAP <score>=(0.977221381984968)
# [10/25/2020 02:07:18 INFO 139771535177536] Updating the best model with validation-mAP=0.977221381984968
# [10/25/2020 02:07:18 INFO 139771535177536] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/25/2020 02:07:18 INFO 139771535177536] #progress_metric: host=algo-1, completed 40 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1603591638.712051, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 5}, "StartTime": 1603591548.206141}
#
# [10/25/2020 02:07:51 INFO 139771535177536] Epoch:    6, batches:    100, num_examples:   1600, 49.3 samples/sec, epoch time so far:  0:00:32.449324
# [10/25/2020 02:08:21 INFO 139771535177536] Epoch:    6, batches:    200, num_examples:   3200, 50.6 samples/sec, epoch time so far:  0:01:03.207470
# [10/25/2020 02:08:26 INFO 139771535177536] #quality_metric: host=algo-1, epoch=6, batch=216 train cross_entropy <loss>=(0.49785354728115744)
# [10/25/2020 02:08:26 INFO 139771535177536] #quality_metric: host=algo-1, epoch=6, batch=216 train smooth_l1 <loss>=(0.25026465468811765)
# [10/25/2020 02:08:26 INFO 139771535177536] Round of batches complete
# [10/25/2020 02:08:26 INFO 139771535177536] Updated the metrics
# [10/25/2020 02:08:48 INFO 139771535177536] #quality_metric: host=algo-1, epoch=6, validation mAP <score>=(0.9875636314737701)
# [10/25/2020 02:08:48 INFO 139771535177536] Updating the best model with validation-mAP=0.9875636314737701
# [10/25/2020 02:08:48 INFO 139771535177536] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/25/2020 02:08:49 INFO 139771535177536] #progress_metric: host=algo-1, completed 46 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1603591729.006806, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 6}, "StartTime": 1603591638.712468}
#
# [10/25/2020 02:09:21 INFO 139771535177536] Epoch:    7, batches:    100, num_examples:   1600, 49.1 samples/sec, epoch time so far:  0:00:32.591946
# [10/25/2020 02:09:52 INFO 139771535177536] Epoch:    7, batches:    200, num_examples:   3200, 50.4 samples/sec, epoch time so far:  0:01:03.517139
# [10/25/2020 02:09:57 INFO 139771535177536] #quality_metric: host=algo-1, epoch=7, batch=216 train cross_entropy <loss>=(0.4756455461466366)
# [10/25/2020 02:09:57 INFO 139771535177536] #quality_metric: host=algo-1, epoch=7, batch=216 train smooth_l1 <loss>=(0.22672481741575828)
# [10/25/2020 02:09:57 INFO 139771535177536] Round of batches complete
# [10/25/2020 02:09:57 INFO 139771535177536] Updated the metrics
# [10/25/2020 02:10:18 INFO 139771535177536] #quality_metric: host=algo-1, epoch=7, validation mAP <score>=(0.988313524261593)
# [10/25/2020 02:10:18 INFO 139771535177536] Updating the best model with validation-mAP=0.988313524261593
# [10/25/2020 02:10:18 INFO 139771535177536] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/25/2020 02:10:18 INFO 139771535177536] #progress_metric: host=algo-1, completed 53 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1603591818.655147, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 7}, "StartTime": 1603591729.007038}
#
# [10/25/2020 02:10:51 INFO 139771535177536] Epoch:    8, batches:    100, num_examples:   1600, 49.3 samples/sec, epoch time so far:  0:00:32.476580
# [10/25/2020 02:11:21 INFO 139771535177536] Epoch:    8, batches:    200, num_examples:   3200, 50.7 samples/sec, epoch time so far:  0:01:03.118271
# [10/25/2020 02:11:26 INFO 139771535177536] #quality_metric: host=algo-1, epoch=8, batch=216 train cross_entropy <loss>=(0.4575013767623825)
# [10/25/2020 02:11:26 INFO 139771535177536] #quality_metric: host=algo-1, epoch=8, batch=216 train smooth_l1 <loss>=(0.20864012784240393)
# [10/25/2020 02:11:26 INFO 139771535177536] Round of batches complete
# [10/25/2020 02:11:26 INFO 139771535177536] Updated the metrics
# [10/25/2020 02:11:49 INFO 139771535177536] #quality_metric: host=algo-1, epoch=8, validation mAP <score>=(0.9878295845012358)
# [10/25/2020 02:11:49 INFO 139771535177536] #progress_metric: host=algo-1, completed 60 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1603591909.372023, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 8}, "StartTime": 1603591818.6555}
#
# [10/25/2020 02:12:21 INFO 139771535177536] Epoch:    9, batches:    100, num_examples:   1600, 49.7 samples/sec, epoch time so far:  0:00:32.171813
# [10/25/2020 02:12:52 INFO 139771535177536] Epoch:    9, batches:    200, num_examples:   3200, 50.7 samples/sec, epoch time so far:  0:01:03.088232
# [10/25/2020 02:12:57 INFO 139771535177536] #quality_metric: host=algo-1, epoch=9, batch=216 train cross_entropy <loss>=(0.4462489455833677)
# [10/25/2020 02:12:57 INFO 139771535177536] #quality_metric: host=algo-1, epoch=9, batch=216 train smooth_l1 <loss>=(0.1972052833200805)
# [10/25/2020 02:12:57 INFO 139771535177536] Round of batches complete
# [10/25/2020 02:12:57 INFO 139771535177536] Updated the metrics
# [10/25/2020 02:13:19 INFO 139771535177536] #quality_metric: host=algo-1, epoch=9, validation mAP <score>=(0.9910880690641415)
# [10/25/2020 02:13:19 INFO 139771535177536] Updating the best model with validation-mAP=0.9910880690641415
# [10/25/2020 02:13:19 INFO 139771535177536] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/25/2020 02:13:19 INFO 139771535177536] #progress_metric: host=algo-1, completed 66 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1603591999.243351, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 9}, "StartTime": 1603591909.372264}
#
# [10/25/2020 02:13:51 INFO 139771535177536] Epoch:    10, batches:    100, num_examples:   1600, 49.0 samples/sec, epoch time so far:  0:00:32.634481
# [10/25/2020 02:14:23 INFO 139771535177536] Epoch:    10, batches:    200, num_examples:   3200, 50.2 samples/sec, epoch time so far:  0:01:03.765353
# [10/25/2020 02:14:28 INFO 139771535177536] #quality_metric: host=algo-1, epoch=10, batch=217 train cross_entropy <loss>=(0.432146326736523)
# [10/25/2020 02:14:28 INFO 139771535177536] #quality_metric: host=algo-1, epoch=10, batch=217 train smooth_l1 <loss>=(0.18987086489232224)
# [10/25/2020 02:14:28 INFO 139771535177536] Round of batches complete
# [10/25/2020 02:14:28 INFO 139771535177536] Updated the metrics
# [10/25/2020 02:14:49 INFO 139771535177536] #quality_metric: host=algo-1, epoch=10, validation mAP <score>=(0.9938266986109823)
# [10/25/2020 02:14:49 INFO 139771535177536] Updating the best model with validation-mAP=0.9938266986109823
# [10/25/2020 02:14:49 INFO 139771535177536] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/25/2020 02:14:49 INFO 139771535177536] #progress_metric: host=algo-1, completed 73 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1603592089.52778, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 10}, "StartTime": 1603591999.243637}
#
# [10/25/2020 02:15:22 INFO 139771535177536] Epoch:    11, batches:    100, num_examples:   1600, 49.1 samples/sec, epoch time so far:  0:00:32.616080
# [10/25/2020 02:15:52 INFO 139771535177536] Epoch:    11, batches:    200, num_examples:   3200, 50.6 samples/sec, epoch time so far:  0:01:03.215508
# [10/25/2020 02:15:57 INFO 139771535177536] #quality_metric: host=algo-1, epoch=11, batch=216 train cross_entropy <loss>=(0.4152960034742256)
# [10/25/2020 02:15:57 INFO 139771535177536] #quality_metric: host=algo-1, epoch=11, batch=216 train smooth_l1 <loss>=(0.175702655790528)
# [10/25/2020 02:15:57 INFO 139771535177536] Round of batches complete
# [10/25/2020 02:15:57 INFO 139771535177536] Updated the metrics
# [10/25/2020 02:16:17 INFO 139771535177536] #quality_metric: host=algo-1, epoch=11, validation mAP <score>=(0.9938234199100444)
# [10/25/2020 02:16:17 INFO 139771535177536] #progress_metric: host=algo-1, completed 80 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1603592177.011609, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 11}, "StartTime": 1603592089.528027}
#
# [10/25/2020 02:16:49 INFO 139771535177536] Epoch:    12, batches:    100, num_examples:   1600, 49.6 samples/sec, epoch time so far:  0:00:32.255200
# [10/25/2020 02:17:19 INFO 139771535177536] Epoch:    12, batches:    200, num_examples:   3200, 51.1 samples/sec, epoch time so far:  0:01:02.614815
# [10/25/2020 02:17:24 INFO 139771535177536] #quality_metric: host=algo-1, epoch=12, batch=216 train cross_entropy <loss>=(0.40546709534302766)
# [10/25/2020 02:17:24 INFO 139771535177536] #quality_metric: host=algo-1, epoch=12, batch=216 train smooth_l1 <loss>=(0.1705292763064175)
# [10/25/2020 02:17:24 INFO 139771535177536] Round of batches complete
# [10/25/2020 02:17:24 INFO 139771535177536] Updated the metrics
# [10/25/2020 02:17:43 INFO 139771535177536] #quality_metric: host=algo-1, epoch=12, validation mAP <score>=(0.9920987031043964)
# [10/25/2020 02:17:43 INFO 139771535177536] #progress_metric: host=algo-1, completed 86 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 13, "sum": 13.0, "min": 13}}, "EndTime": 1603592263.708938, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 12}, "StartTime": 1603592177.015407}
#
# [10/25/2020 02:18:15 INFO 139771535177536] Epoch:    13, batches:    100, num_examples:   1600, 50.7 samples/sec, epoch time so far:  0:00:31.537369
# [10/25/2020 02:18:45 INFO 139771535177536] Epoch:    13, batches:    200, num_examples:   3200, 51.4 samples/sec, epoch time so far:  0:01:02.199874
# [10/25/2020 02:18:50 INFO 139771535177536] #quality_metric: host=algo-1, epoch=13, batch=216 train cross_entropy <loss>=(0.3945468291782845)
# [10/25/2020 02:18:50 INFO 139771535177536] #quality_metric: host=algo-1, epoch=13, batch=216 train smooth_l1 <loss>=(0.16243014739224904)
# [10/25/2020 02:18:50 INFO 139771535177536] Round of batches complete
# [10/25/2020 02:18:50 INFO 139771535177536] Updated the metrics
# [10/25/2020 02:19:09 INFO 139771535177536] #quality_metric: host=algo-1, epoch=13, validation mAP <score>=(0.9933522243202104)
# [10/25/2020 02:19:09 INFO 139771535177536] #progress_metric: host=algo-1, completed 93 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1603592349.276638, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 13}, "StartTime": 1603592263.709155}
#
# [10/25/2020 02:19:41 INFO 139771535177536] Epoch:    14, batches:    100, num_examples:   1600, 49.9 samples/sec, epoch time so far:  0:00:32.080741
# [10/25/2020 02:20:11 INFO 139771535177536] Epoch:    14, batches:    200, num_examples:   3200, 51.1 samples/sec, epoch time so far:  0:01:02.662313
# [10/25/2020 02:20:16 INFO 139771535177536] #quality_metric: host=algo-1, epoch=14, batch=216 train cross_entropy <loss>=(0.38340392144249463)
# [10/25/2020 02:20:16 INFO 139771535177536] #quality_metric: host=algo-1, epoch=14, batch=216 train smooth_l1 <loss>=(0.15681420547931824)
# [10/25/2020 02:20:16 INFO 139771535177536] Round of batches complete
# [10/25/2020 02:20:16 INFO 139771535177536] Updated the metrics
#
# 2020-10-25 02:20:35 Uploading - Uploading generated training model[10/25/2020 02:20:33 INFO 139771535177536] #quality_metric: host=algo-1, epoch=14, validation mAP <score>=(0.9940241782842956)
# [10/25/2020 02:20:33 INFO 139771535177536] Updating the best model with validation-mAP=0.9940241782842956
# [10/25/2020 02:20:33 INFO 139771535177536] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/25/2020 02:20:33 INFO 139771535177536] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1603592433.983781, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 14}, "StartTime": 1603592349.276913}
#
# [10/25/2020 02:20:33 WARNING 139771535177536] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/25/2020 02:20:34 INFO 139771535177536] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/25/2020 02:20:34 INFO 139771535177536] Test data is not provided.
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}, "totaltime": {"count": 1, "max": 1371017.4469947815, "sum": 1371017.4469947815, "min": 1371017.4469947815}, "setuptime": {"count": 1, "max": 10.483980178833008, "sum": 10.483980178833008, "min": 10.483980178833008}}, "EndTime": 1603592435.158185, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1603591064.269963}
#
#
# 2020-10-25 02:20:52 Completed - Training job completed
# Training seconds: 1534
# Billable seconds: 1534

# %% [markdown]
# # Deploy Model

# %%
print('\nDeploying model...')
deployed_model = model.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
print('\nModel deployed!')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# Deploying model...
# ---------------!
# Model deployed!

# %% [markdown]
# # Predictions

# %%
image_dir = 'validation'
images = [x for x in os.listdir(image_dir) if x[-3:] == 'jpg']
print(len(images))
# Out:
# 950

# %%
deployed_model.content_type = 'image/jpeg'

# %%
index = 0

image_path = os.path.join(image_dir, images[index])
#image_path = 'dog_cat.jfif'

with open(image_path, 'rb') as f:
    b = bytearray(f.read())

results = deployed_model.predict(b)
results = json.loads(results)

preds = results['prediction']

# %%
preds
# Out:
# [[0.0,
#   0.9732837677001953,
#   0.19273558259010315,
#   0.0,
#   0.6807836294174194,
#   0.4183937907218933],
#  [1.0,
#   0.14384865760803223,
#   0.11392912268638611,
#   0.007816284894943237,
#   0.7962992191314697,
#   0.5107110738754272],
#  [1.0,
#   0.09665457159280777,
#   0.08643195033073425,
#   0.0868552029132843,
#   0.9279506206512451,
#   0.8974376916885376],
#  [1.0,
#   0.05491240322589874,
#   0.22927619516849518,
#   0.05297597497701645,
#   0.3069223165512085,
#   0.18352437019348145],
#  [1.0,
#   0.03653571754693985,
#   0.204347163438797,
#   0.05196186900138855,
#   0.27503472566604614,
#   0.18096937239170074],
#  [0.0, 0.035575490444898605, 0.0, 0.949350118637085, 0.07808437943458557, 1.0],
#  [1.0,
#   0.031023383140563965,
#   0.4801424741744995,
#   0.26286861300468445,
#   0.9920268058776855,
#   1.0],
#  [0.0,
#   0.02939830720424652,
#   0.058330804109573364,
#   0.9162689447402954,
#   0.22031858563423157,
#   1.0],
#  [0.0,
#   0.025258183479309082,
#   0.14846840500831604,
#   0.9154741764068604,
#   0.3126140534877777,
#   1.0],
#  [0.0,
#   0.02322172001004219,
#   0.13535568118095398,
#   0.9486646056175232,
#   0.27405598759651184,
#   1.0],
#  [0.0,
#   0.023011984303593636,
#   0.4034574627876282,
#   0.9093737006187439,
#   0.5652331113815308,
#   1.0],
#  [0.0,
#   0.022543804720044136,
#   0.5093172788619995,
#   0.04226335138082504,
#   0.6530181169509888,
#   0.19505572319030762],
#  [0.0,
#   0.019857320934534073,
#   0.7452463507652283,
#   0.9154694676399231,
#   0.9092105031013489,
#   1.0],
#  [1.0,
#   0.019114356487989426,
#   0.20431587100028992,
#   0.07105337828397751,
#   0.3316846191883087,
#   0.15120619535446167],
#  [0.0,
#   0.01789582334458828,
#   0.34923624992370605,
#   0.9065151810646057,
#   0.5017313361167908,
#   1.0],
#  [1.0,
#   0.017859237268567085,
#   0.17603035271167755,
#   0.05362527817487717,
#   0.24230624735355377,
#   0.17837584018707275],
#  [0.0,
#   0.01755474880337715,
#   0.7273241877555847,
#   0.9503821134567261,
#   0.864899218082428,
#   1.0],
#  [0.0,
#   0.01755017787218094,
#   0.04221627116203308,
#   0.9507564306259155,
#  [1.0,
#   0.010308824479579926,
#   0.5451279878616333,
#   0.4459894299507141,
#   0.6801667213439941,
#   0.5161294341087341],
#  [1.0,
#   0.01030380092561245,
#   0.0,
#   0.41454964876174927,
#   0.07498174160718918,
#   0.4873478412628174],
#  [1.0,
#   0.01029166765511036,
#   0.0,
#   0.8839754462242126,
#   0.0799872875213623,
#   0.9561757445335388],
#  [1.0,
#   0.01027199812233448,
#   0.9079442620277405,
#   0.6475545167922974,
#   1.0,
#   0.8095231056213379],
#  [1.0,
#   0.010189587250351906,
#   0.0,
#   0.6712278127670288,
#   0.051279790699481964,
#   0.8019163608551025],
#  [1.0,
#   0.010187881998717785,
#   0.04480862617492676,
#   0.6448767781257629,
#   0.11599135398864746,
#   0.7699094414710999],
#  [1.0,
#   0.010148310102522373,
#   0.0,
#   0.29250574111938477,
#   0.07416751980781555,
#   0.36233216524124146],
#  [1.0,
#   0.010146410204470158,
#   0.0,
#   0.3840752840042114,
#   0.07428766787052155,
#   0.4574427008628845],
#  [1.0,
#   0.010129939764738083,
#   0.4928762912750244,
#   0.6444416642189026,
#   0.6519855260848999,
#   0.825530469417572],
#  [1.0,
#   0.01010886300355196,
#   0.0,
#   0.7608677744865417,
#   0.07812143862247467,
#   0.8327190279960632],
#  [1.0,
#   0.01010706927627325,
#   0.6365705132484436,
#   0.6487566828727722,
#   0.7094057202339172,
#   0.7712710499763489]]

# %%
img = Image.open(image_path)
draw = ImageDraw.Draw(img)
font = ImageFont.truetype('/usr/share/fonts/dejavu/DejaVuSerif-Bold.ttf', 30)
w, h =img.size

for pred in preds:
    class_id, score, xmin, ymin, xmax, ymax = pred
    
    if score > 0.7:
        box = [w*xmin, h*ymin, w*xmax, h*ymax]

        draw.rectangle(box, outline='yellow', width=4)
        draw.text((box[0], box[1]), classes[int(class_id)], font=font, fill='#000000')
    else:
        break

plt.xticks([])
plt.yticks([])
plt.imshow(img)
plt.show()

# %%
sagemaker.Session().delete_endpoint(deployed_model.endpoint)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-32-cd5fe9a3b9ac> in <module>
# ----> 1 sagemaker.Session().delete_endpoint(deployed_model.endpoint)
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/sagemaker/session.py in delete_endpoint(self, endpoint_name)
#    2468         """
#    2469         LOGGER.info("Deleting endpoint with name: %s", endpoint_name)
# -> 2470         self.sagemaker_client.delete_endpoint(EndpointName=endpoint_name)
#    2471
#    2472     def delete_endpoint_config(self, endpoint_config_name):
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     674             error_code = parsed_response.get("Error", {}).get("Code")
#     675             error_class = self.exceptions.from_code(error_code)
# --> 676             raise error_class(parsed_response, operation_name)
#     677         else:
#     678             return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the DeleteEndpoint operation: Could not find endpoint "arn:aws:sagemaker:us-east-2:220358287762:endpoint/object-detection-2020-10-25-01-52-56-019".
