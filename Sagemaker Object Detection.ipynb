# %% [markdown]
# # Download the Data

# %%
# %matplotlib inline

import os
import tarfile
import urllib
import shutil
import json
import random
import numpy as np
import boto3
import sagemaker

from tqdm import tqdm
from sagemaker.amazon.amazon_estimator import get_image_uri
from matplotlib import pyplot as plt
from xml.etree import ElementTree as ET
from PIL import Image, ImageDraw, ImageFont

urls = ['http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz',
        'http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz']

def download_and_extract(data_dir, download_dir):
    for url in urls:
        target_file = url.split('/')[-1]
        if target_file not in os.listdir(download_dir):
            print('Downloading', url)
            urllib.request.urlretrieve(url, os.path.join(download_dir, target_file))
            tf = tarfile.open(url.split('/')[-1])
            tf.extractall(data_dir)
        else:
            print('Already downloaded', url)

if not os.path.isdir('data'):
    os.mkdir('data')

download_and_extract('data', '.')
# Out:
# Already downloaded http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Already downloaded http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz

# %% [markdown]
# # Extracting Annotations from XML Format

# %%
xml_dir = 'data/annotations/xmls/'
xml_files = [os.path.join(xml_dir, x) for x in os.listdir(xml_dir) if x[-3:] == 'xml']
xml_files[0]
# Out:
# 'data/annotations/xmls/Sphynx_206.xml'

# %%
classes = ['cat', 'dog']
categories = [
    {
        'class_id': 0,
        'name': 'cat'
    },
    {
        'class_id': 1,
        'name': 'dog'
    }
]

# %%
def extract_annotation(xml_file_path):
    
    tree = ET.parse(xml_file_path)
    root = tree.getroot()
    annotation = {}
    
    annotation['file'] = root.find('filename').text
    annotation['categories'] = categories
    
    size = root.find('size')
    
    annotation['image_size'] = [{
        'width': int(size.find('width').text),
        'height': int(size.find('height').text),
        'depth': int(size.find('depth').text)
    }]
    
    annotation['annotations'] = []
    
    for item in root.iter('object'):
        class_id = classes.index(item.find('name').text)
        ymin, xmin, ymax, xmax = None, None, None, None
        
        for box in item.findall('bndbox'):
            xmin = int(box.find("xmin").text)
            ymin = int(box.find("ymin").text)
            xmax = int(box.find("xmax").text)
            ymax = int(box.find("ymax").text)
        
            if all([xmin, ymin, xmax, ymax]) is not None:
                 annotation['annotations'].append({
                     'class_id': class_id,
                     'left': xmin,
                     'top': ymin,
                     'width': xmax - xmin,
                     'height': ymax - ymin
                 })
    return annotation

# %%
extract_annotation(xml_files[0])
# Out:
# {'file': 'Sphynx_206.jpg',
#  'categories': [{'class_id': 0, 'name': 'cat'},
#   {'class_id': 1, 'name': 'dog'}],
#  'image_size': [{'width': 345, 'height': 500, 'depth': 3}],
#  'annotations': [{'class_id': 0,
#    'left': 85,
#    'top': 19,
#    'width': 260,
#    'height': 280}]}

# %% [markdown]
# # Visualize Data

# %%
def plot_example(plt, annot, image_file_path, rows, cols, index):
    img = Image.open(image_file_path)
    draw = ImageDraw.Draw(img)
    font = ImageFont.truetype('/usr/share/fonts/dejavu/DejaVuSansCondensed-Bold.ttf', 25)
    
    for a in annot['annotations']:
        box = [
            int(a['left']), int(a['top']),
            int(a['left']) + int(a['width']),
            int(a['top']) + int(a['height'])
        ]
        draw.rectangle(box, outline='red', width=4)
        draw.text((box[0], box[1]), classes[int(a['class_id'])], font=font)
    plt.subplot(rows, cols, index + 1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img)
    return plt

def show_random_annotations(plt):
    plt.figure(figsize=(16, 16))
    for i in range(0, 9):
        index = random.randint(0, len(xml_files) - 1)
        
        annot = extract_annotation(xml_files[index])
        image_file_path = os.path.join('data/images/', annot['file'])

        plt = plot_example(plt, annot, image_file_path, 3, 3, i)
    plt.show()

# %%
show_random_annotations(plt)

# %% [markdown]
# # SageMaker Setup

# %%
role = sagemaker.get_execution_role()

bucket_name = 'petsdata26'

training_image = get_image_uri(boto3.Session().region_name, 'object-detection', repo_version='latest')
print(training_image)
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 825641698319.dkr.ecr.us-east-2.amazonaws.com/object-detection:latest

# %%
folders = ['train', 'train_annotation', 'validation', 'validation_annotation']

for folder in folders:
    if os.path.isdir(folder):
        shutil.rmtree(folder)
    os.mkdir(folder)

# %% [markdown]
# # Preparing Data for SageMaker

# %%
print('Total examples:', len(xml_files))
# Out:
# Total examples: 3686

# %%
for xml_file in tqdm(xml_files):
    target_set = 'train' if random.randint(0, 99) < 75 else 'validation'
    annot = extract_annotation(xml_file)
    image_file_path = os.path.join('data/images/', annot['file'])
    image_target_path = os.path.join(target_set, annot['file'])
    shutil.copy(image_file_path, image_target_path)
    json_file_path = os.path.join(target_set + '_annotation', annot['file'][:-3] + 'json')
    with open(json_file_path, 'w') as f:
        json.dump(annot, f)
# Out:
# 100%|██████████| 3686/3686 [02:35<00:00, 23.77it/s]

# %%
train_images = os.listdir('train')
train_annots = os.listdir('train_annotation')

# %%
print(len(train_annots), len(train_images))
# Out:
# 2748 2748

# %%
for image in train_images:
    key = image.split('.')[0]
    json_file = key + '.json'
    if json_file not in train_annots:
        print('Not found', json_file)

# %% [markdown]
# # Uploading Data to S3

# %%
sess = sagemaker.Session()

print('Uploading data...')

s3_training_path = sess.upload_data(path='train', bucket=bucket_name, key_prefix='train')
print('Training images uploaded')

s3_validation_path = sess.upload_data(path='validation', bucket=bucket_name, key_prefix='validation')
print('Validation images uploaded')

s3_train_annotation = sess.upload_data(path='train_annotation', bucket=bucket_name, key_prefix='train_annotation')
print('Training annotations uploaded')

s3_validation_annotation = sess.upload_data(path='validation_annotation', bucket=bucket_name, key_prefix='validation_annotation')
print('Validation annotations uploaded')
# Out:
# Uploading data...
# Training images uploaded
# Validation images uploaded
# Training annotations uploaded
# Validation annotations uploaded

# %%
s3_validation_annotation
# Out:
# 's3://petsdata26/validation_annotation'

# %% [markdown]
# # SageMaker Estimator

# %%
model = sagemaker.estimator.Estimator(
    training_image,
    role = role,
    train_instance_type = 'ml.p3.2xlarge',
    train_instance_count = 1,
    train_volume_size = 100,
    train_max_run = 36000,
    input_mode = 'File',
    output_path = 's3://petsdata26/output',
    sagemaker_session = sess)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# # Hyperparameters

# %%
model.set_hyperparameters(
    base_network='resnet-50',
    num_classes=2,
    use_pretrained_model=1,
    mini_batch_size=16,
    epochs=15,
    learning_rate=0.001,
    optimizer='sgd',
    lr_scheduler_step='10',
    lr_scheduler_factor=0.1,
    momentum=0.9,
    weight_decay=0.0005,
    overlap_threshold=0.5,
    nms_threshold=0.45,
    image_shape=512,
    num_training_samples=len(train_annots)
)

# %% [markdown]
# # Data Channels

# %%
from sagemaker.session import s3_input

train_data = s3_input(s3_training_path, distribution = 'FullyReplicated',
                      content_type = 'application/x-image', s3_data_type = 'S3Prefix')

validation_data = s3_input(s3_validation_path, distribution = 'FullyReplicated',
                      content_type = 'application/x-image', s3_data_type = 'S3Prefix')

train_annotation_data = s3_input(s3_train_annotation, distribution = 'FullyReplicated',
                      content_type = 'application/x-image', s3_data_type = 'S3Prefix')

validation_annotation_data = s3_input(s3_validation_annotation, distribution = 'FullyReplicated',
                      content_type = 'application/x-image', s3_data_type = 'S3Prefix')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
data_channels = {
    'train': train_data,
    'validation': validation_data,
    'train_annotation': train_annotation_data,
    'validation_annotation': validation_annotation_data
}

# %%
data_channels
# Out:
# {'train': <sagemaker.inputs.s3_input at 0x7ff181ecc978>,
#  'validation': <sagemaker.inputs.s3_input at 0x7ff180c369e8>,
#  'train_annotation': <sagemaker.inputs.s3_input at 0x7ff1804ad550>,
#  'validation_annotation': <sagemaker.inputs.s3_input at 0x7ff1804ad9e8>}

# %% [markdown]
# # Model Training

# %%
model.fit(inputs = data_channels, logs = True)
# Out:
# 2020-10-29 04:08:07 Starting - Starting the training job...
# 2020-10-29 04:08:09 Starting - Launching requested ML instances......
# 2020-10-29 04:09:16 Starting - Preparing the instances for training......
# 2020-10-29 04:10:26 Downloading - Downloading input data.........
# 2020-10-29 04:12:08 Training - Downloading the training image...
# 2020-10-29 04:12:28 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# [10/29/2020 04:12:32 INFO 140695859349312] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'30', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'32', u'use_pretrained_model': u'0', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'', u'base_network': u'vgg-16', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'300'}
# [10/29/2020 04:12:32 INFO 140695859349312] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'learning_rate': u'0.001', u'epochs': u'15', u'nms_threshold': u'0.45', u'optimizer': u'sgd', u'base_network': u'resnet-50', u'image_shape': u'512', u'lr_scheduler_step': u'10', u'momentum': u'0.9', u'overlap_threshold': u'0.5', u'num_training_samples': u'2748', u'mini_batch_size': u'16', u'weight_decay': u'0.0005', u'use_pretrained_model': u'1', u'num_classes': u'2', u'lr_scheduler_factor': u'0.1'}
# [10/29/2020 04:12:32 INFO 140695859349312] Final configuration: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'15', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'16', u'use_pretrained_model': u'1', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'10', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'2748', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'2', u'base_network': u'resnet-50', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'512'}
# Process 1 is a worker.
# [10/29/2020 04:12:32 INFO 140695859349312] Using default worker.
# [10/29/2020 04:12:33 INFO 140695859349312] Loaded iterator creator application/x-image for content type ('application/x-image', '1.0')
# [10/29/2020 04:12:33 INFO 140695859349312] Loaded iterator creator application/x-recordio for content type ('application/x-recordio', '1.0')
# [10/29/2020 04:12:33 INFO 140695859349312] Loaded iterator creator image/png for content type ('image/png', '1.0')
# [10/29/2020 04:12:33 INFO 140695859349312] Loaded iterator creator image/jpeg for content type ('image/jpeg', '1.0')
# [10/29/2020 04:12:33 INFO 140695859349312] Checkpoint loading and saving are disabled.
# [10/29/2020 04:12:34 INFO 140695859349312] nvidia-smi took: 0.025269985199 secs to identify 1 gpus
# Creating .rec file from /opt/ml/input/data/train/train.lst in /opt/ml/input/data/train
# time: 0.0358788967133  count: 0
# time: 1.46920108795  count: 1000
# time: 1.10614490509  count: 2000
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# time: 1.27414107323  count: 3000
# Creating .rec file from /opt/ml/input/data/validation/val.lst in /opt/ml/input/data/validation
# time: 0.0220818519592  count: 0
# time: 1.28618907928  count: 1000
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# time: 1.95197701454  count: 2000
# [10/29/2020 04:12:45 INFO 140695859349312] Number of GPUs being used: 1
# [10/29/2020 04:12:45 WARNING 140695859349312] Training images are resized to image shape (3, 512, 512)
# [04:12:45] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, use 7 threads for decoding..
# [04:12:45] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, label padding width: 350
# [10/29/2020 04:12:47 WARNING 140695859349312] Validation images are resized to image shape (3, 512, 512)
# [04:12:47] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, use 7 threads for decoding..
# [04:12:47] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, label padding width: 350
# [10/29/2020 04:12:50 INFO 140695859349312] Number of GPUs being used: 1
# [10/29/2020 04:12:50 INFO 140695859349312] Using [gpu(0)] as training context.
# [10/29/2020 04:12:50 INFO 140695859349312] Number of GPUs being used: 1
# [10/29/2020 04:12:50 INFO 140695859349312] Create Store: device
# [10/29/2020 04:12:50 INFO 140695859349312] Using (gpu(0)) as training context.
# [10/29/2020 04:12:50 INFO 140695859349312] Start training from pretrained model 1.
# [04:12:50] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [04:12:50] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# [10/29/2020 04:12:51 INFO 140695859349312] Loaded pretrained model parameters.
# [10/29/2020 04:13:06 INFO 140695859349312] Creating a new state instance.
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1603944786.742768, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1603944786.742662}
#
# [04:13:06] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [10/29/2020 04:13:44 INFO 140695859349312] Epoch:    0, batches:    100, num_examples:   1600, 42.1 samples/sec, epoch time so far:  0:00:37.965771
# [10/29/2020 04:14:16 INFO 140695859349312] Epoch:    0, batches:    200, num_examples:   3200, 46.1 samples/sec, epoch time so far:  0:01:09.433304
# [10/29/2020 04:14:24 INFO 140695859349312] #quality_metric: host=algo-1, epoch=0, batch=227 train cross_entropy <loss>=(1.0643581145308696)
# [10/29/2020 04:14:24 INFO 140695859349312] #quality_metric: host=algo-1, epoch=0, batch=227 train smooth_l1 <loss>=(0.62843747203035)
# [10/29/2020 04:14:24 INFO 140695859349312] Round of batches complete
# [10/29/2020 04:14:24 INFO 140695859349312] Updated the metrics
# [10/29/2020 04:14:51 INFO 140695859349312] #quality_metric: host=algo-1, epoch=0, validation mAP <score>=(0.19354762004229847)
# [10/29/2020 04:14:51 INFO 140695859349312] Updating the best model with validation-mAP=0.19354762004229847
# [10/29/2020 04:14:51 INFO 140695859349312] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/29/2020 04:14:51 INFO 140695859349312] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1603944891.826984, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 0}, "StartTime": 1603944786.743147}
#
# [10/29/2020 04:15:24 INFO 140695859349312] Epoch:    1, batches:    100, num_examples:   1600, 48.7 samples/sec, epoch time so far:  0:00:32.854924
# [10/29/2020 04:15:56 INFO 140695859349312] Epoch:    1, batches:    200, num_examples:   3200, 49.5 samples/sec, epoch time so far:  0:01:04.594942
# [10/29/2020 04:16:04 INFO 140695859349312] #quality_metric: host=algo-1, epoch=1, batch=226 train cross_entropy <loss>=(0.7882748107415334)
# [10/29/2020 04:16:04 INFO 140695859349312] #quality_metric: host=algo-1, epoch=1, batch=226 train smooth_l1 <loss>=(0.5573910607641067)
# [10/29/2020 04:16:04 INFO 140695859349312] Round of batches complete
# [10/29/2020 04:16:04 INFO 140695859349312] Updated the metrics
# [10/29/2020 04:16:29 INFO 140695859349312] #quality_metric: host=algo-1, epoch=1, validation mAP <score>=(0.49927040784364746)
# [10/29/2020 04:16:29 INFO 140695859349312] Updating the best model with validation-mAP=0.49927040784364746
# [10/29/2020 04:16:29 INFO 140695859349312] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/29/2020 04:16:29 INFO 140695859349312] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1603944989.932851, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 1}, "StartTime": 1603944891.827282}
#
# [10/29/2020 04:17:02 INFO 140695859349312] Epoch:    2, batches:    100, num_examples:   1600, 48.7 samples/sec, epoch time so far:  0:00:32.855430
# [10/29/2020 04:17:34 INFO 140695859349312] Epoch:    2, batches:    200, num_examples:   3200, 49.7 samples/sec, epoch time so far:  0:01:04.340414
# [10/29/2020 04:17:42 INFO 140695859349312] #quality_metric: host=algo-1, epoch=2, batch=226 train cross_entropy <loss>=(0.6631720932865223)
# [10/29/2020 04:17:42 INFO 140695859349312] #quality_metric: host=algo-1, epoch=2, batch=226 train smooth_l1 <loss>=(0.4735870215740106)
# [10/29/2020 04:17:42 INFO 140695859349312] Round of batches complete
# [10/29/2020 04:17:42 INFO 140695859349312] Updated the metrics
# [10/29/2020 04:18:09 INFO 140695859349312] #quality_metric: host=algo-1, epoch=2, validation mAP <score>=(0.7787040036561047)
# [10/29/2020 04:18:09 INFO 140695859349312] Updating the best model with validation-mAP=0.7787040036561047
# [10/29/2020 04:18:09 INFO 140695859349312] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/29/2020 04:18:09 INFO 140695859349312] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1603945089.301449, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 2}, "StartTime": 1603944989.933122}
#
# [10/29/2020 04:18:42 INFO 140695859349312] Epoch:    3, batches:    100, num_examples:   1600, 48.6 samples/sec, epoch time so far:  0:00:32.897326
# [10/29/2020 04:19:13 INFO 140695859349312] Epoch:    3, batches:    200, num_examples:   3200, 49.6 samples/sec, epoch time so far:  0:01:04.458381
# [10/29/2020 04:19:21 INFO 140695859349312] #quality_metric: host=algo-1, epoch=3, batch=226 train cross_entropy <loss>=(0.5956046889623855)
# [10/29/2020 04:19:21 INFO 140695859349312] #quality_metric: host=algo-1, epoch=3, batch=226 train smooth_l1 <loss>=(0.37894632432666203)
# [10/29/2020 04:19:21 INFO 140695859349312] Round of batches complete
# [10/29/2020 04:19:21 INFO 140695859349312] Updated the metrics
# [10/29/2020 04:19:50 INFO 140695859349312] #quality_metric: host=algo-1, epoch=3, validation mAP <score>=(0.908573935764575)
# [10/29/2020 04:19:50 INFO 140695859349312] Updating the best model with validation-mAP=0.908573935764575
# [10/29/2020 04:19:50 INFO 140695859349312] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/29/2020 04:19:50 INFO 140695859349312] #progress_metric: host=algo-1, completed 26 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1603945190.302651, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 3}, "StartTime": 1603945089.301758}
#
# [10/29/2020 04:20:23 INFO 140695859349312] Epoch:    4, batches:    100, num_examples:   1600, 48.8 samples/sec, epoch time so far:  0:00:32.788790
# [10/29/2020 04:20:54 INFO 140695859349312] Epoch:    4, batches:    200, num_examples:   3200, 49.8 samples/sec, epoch time so far:  0:01:04.236308
# [10/29/2020 04:21:02 INFO 140695859349312] #quality_metric: host=algo-1, epoch=4, batch=226 train cross_entropy <loss>=(0.5576757098036144)
# [10/29/2020 04:21:02 INFO 140695859349312] #quality_metric: host=algo-1, epoch=4, batch=226 train smooth_l1 <loss>=(0.32189354980877954)
# [10/29/2020 04:21:02 INFO 140695859349312] Round of batches complete
# [10/29/2020 04:21:02 INFO 140695859349312] Updated the metrics
# [10/29/2020 04:21:30 INFO 140695859349312] #quality_metric: host=algo-1, epoch=4, validation mAP <score>=(0.9659470938193999)
# [10/29/2020 04:21:30 INFO 140695859349312] Updating the best model with validation-mAP=0.9659470938193999
# [10/29/2020 04:21:30 INFO 140695859349312] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/29/2020 04:21:30 INFO 140695859349312] #progress_metric: host=algo-1, completed 33 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1603945290.932687, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 4}, "StartTime": 1603945190.302911}
#
# [10/29/2020 04:22:03 INFO 140695859349312] Epoch:    5, batches:    100, num_examples:   1600, 48.8 samples/sec, epoch time so far:  0:00:32.759178
# [10/29/2020 04:22:35 INFO 140695859349312] Epoch:    5, batches:    200, num_examples:   3200, 49.7 samples/sec, epoch time so far:  0:01:04.432065
# [10/29/2020 04:22:43 INFO 140695859349312] #quality_metric: host=algo-1, epoch=5, batch=226 train cross_entropy <loss>=(0.5167403157966998)
# [10/29/2020 04:22:43 INFO 140695859349312] #quality_metric: host=algo-1, epoch=5, batch=226 train smooth_l1 <loss>=(0.27303788915999505)
# [10/29/2020 04:22:43 INFO 140695859349312] Round of batches complete
# [10/29/2020 04:22:43 INFO 140695859349312] Updated the metrics
# [10/29/2020 04:23:11 INFO 140695859349312] #quality_metric: host=algo-1, epoch=5, validation mAP <score>=(0.974959297416697)
# [10/29/2020 04:23:11 INFO 140695859349312] Updating the best model with validation-mAP=0.974959297416697
# [10/29/2020 04:23:11 INFO 140695859349312] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/29/2020 04:23:11 INFO 140695859349312] #progress_metric: host=algo-1, completed 40 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1603945391.816334, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 5}, "StartTime": 1603945290.933035}
#
# [10/29/2020 04:23:43 INFO 140695859349312] Epoch:    6, batches:    100, num_examples:   1600, 49.8 samples/sec, epoch time so far:  0:00:32.144221
# [10/29/2020 04:24:15 INFO 140695859349312] Epoch:    6, batches:    200, num_examples:   3200, 50.4 samples/sec, epoch time so far:  0:01:03.438978
# [10/29/2020 04:24:23 INFO 140695859349312] #quality_metric: host=algo-1, epoch=6, batch=226 train cross_entropy <loss>=(0.4879343108415085)
# [10/29/2020 04:24:23 INFO 140695859349312] #quality_metric: host=algo-1, epoch=6, batch=226 train smooth_l1 <loss>=(0.24385496591758793)
# [10/29/2020 04:24:23 INFO 140695859349312] Round of batches complete
# [10/29/2020 04:24:23 INFO 140695859349312] Updated the metrics
# [10/29/2020 04:24:52 INFO 140695859349312] #quality_metric: host=algo-1, epoch=6, validation mAP <score>=(0.9853727035915314)
# [10/29/2020 04:24:52 INFO 140695859349312] Updating the best model with validation-mAP=0.9853727035915314
# [10/29/2020 04:24:52 INFO 140695859349312] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/29/2020 04:24:52 INFO 140695859349312] #progress_metric: host=algo-1, completed 46 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1603945492.45604, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 6}, "StartTime": 1603945391.81659}
#
# [10/29/2020 04:25:25 INFO 140695859349312] Epoch:    7, batches:    100, num_examples:   1600, 48.9 samples/sec, epoch time so far:  0:00:32.728912
# [10/29/2020 04:25:56 INFO 140695859349312] Epoch:    7, batches:    200, num_examples:   3200, 50.1 samples/sec, epoch time so far:  0:01:03.865650
# [10/29/2020 04:26:03 INFO 140695859349312] #quality_metric: host=algo-1, epoch=7, batch=226 train cross_entropy <loss>=(0.47232215298951125)
# [10/29/2020 04:26:03 INFO 140695859349312] #quality_metric: host=algo-1, epoch=7, batch=226 train smooth_l1 <loss>=(0.225525432906988)
# [10/29/2020 04:26:03 INFO 140695859349312] Round of batches complete
# [10/29/2020 04:26:03 INFO 140695859349312] Updated the metrics
# [10/29/2020 04:26:32 INFO 140695859349312] #quality_metric: host=algo-1, epoch=7, validation mAP <score>=(0.9857251121588253)
# [10/29/2020 04:26:32 INFO 140695859349312] Updating the best model with validation-mAP=0.9857251121588253
# [10/29/2020 04:26:32 INFO 140695859349312] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/29/2020 04:26:32 INFO 140695859349312] #progress_metric: host=algo-1, completed 53 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1603945592.649078, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 7}, "StartTime": 1603945492.456296}
#
# [10/29/2020 04:27:06 INFO 140695859349312] Epoch:    8, batches:    100, num_examples:   1600, 46.6 samples/sec, epoch time so far:  0:00:34.328786
# [10/29/2020 04:27:38 INFO 140695859349312] Epoch:    8, batches:    200, num_examples:   3200, 48.9 samples/sec, epoch time so far:  0:01:05.418572
# [10/29/2020 04:27:46 INFO 140695859349312] #quality_metric: host=algo-1, epoch=8, batch=227 train cross_entropy <loss>=(0.45305559121488465)
# [10/29/2020 04:27:46 INFO 140695859349312] #quality_metric: host=algo-1, epoch=8, batch=227 train smooth_l1 <loss>=(0.20612493103046167)
# [10/29/2020 04:27:46 INFO 140695859349312] Round of batches complete
# [10/29/2020 04:27:46 INFO 140695859349312] Updated the metrics
# [10/29/2020 04:28:14 INFO 140695859349312] #quality_metric: host=algo-1, epoch=8, validation mAP <score>=(0.9887591857525395)
# [10/29/2020 04:28:14 INFO 140695859349312] Updating the best model with validation-mAP=0.9887591857525395
# [10/29/2020 04:28:14 INFO 140695859349312] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/29/2020 04:28:14 INFO 140695859349312] #progress_metric: host=algo-1, completed 60 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1603945694.2266, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 8}, "StartTime": 1603945592.64936}
#
# [10/29/2020 04:28:46 INFO 140695859349312] Epoch:    9, batches:    100, num_examples:   1600, 49.4 samples/sec, epoch time so far:  0:00:32.395436
# [10/29/2020 04:29:17 INFO 140695859349312] Epoch:    9, batches:    200, num_examples:   3200, 50.3 samples/sec, epoch time so far:  0:01:03.639397
# [10/29/2020 04:29:25 INFO 140695859349312] #quality_metric: host=algo-1, epoch=9, batch=226 train cross_entropy <loss>=(0.4433519344417461)
# [10/29/2020 04:29:25 INFO 140695859349312] #quality_metric: host=algo-1, epoch=9, batch=226 train smooth_l1 <loss>=(0.19256161077099226)
# [10/29/2020 04:29:25 INFO 140695859349312] Round of batches complete
# [10/29/2020 04:29:25 INFO 140695859349312] Updated the metrics
# [10/29/2020 04:29:54 INFO 140695859349312] #quality_metric: host=algo-1, epoch=9, validation mAP <score>=(0.9909814994818251)
# [10/29/2020 04:29:54 INFO 140695859349312] Updating the best model with validation-mAP=0.9909814994818251
# [10/29/2020 04:29:54 INFO 140695859349312] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/29/2020 04:29:54 INFO 140695859349312] #progress_metric: host=algo-1, completed 66 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1603945794.314755, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 9}, "StartTime": 1603945694.226913}
#
# [10/29/2020 04:30:26 INFO 140695859349312] Epoch:    10, batches:    100, num_examples:   1600, 49.4 samples/sec, epoch time so far:  0:00:32.359032
# [10/29/2020 04:30:57 INFO 140695859349312] Epoch:    10, batches:    200, num_examples:   3200, 50.4 samples/sec, epoch time so far:  0:01:03.471444
# [10/29/2020 04:31:05 INFO 140695859349312] #quality_metric: host=algo-1, epoch=10, batch=226 train cross_entropy <loss>=(0.4260763236301856)
# [10/29/2020 04:31:05 INFO 140695859349312] #quality_metric: host=algo-1, epoch=10, batch=226 train smooth_l1 <loss>=(0.1819008504845881)
# [10/29/2020 04:31:05 INFO 140695859349312] Round of batches complete
# [10/29/2020 04:31:05 INFO 140695859349312] Updated the metrics
# [10/29/2020 04:31:34 INFO 140695859349312] #quality_metric: host=algo-1, epoch=10, validation mAP <score>=(0.9923706391292801)
# [10/29/2020 04:31:34 INFO 140695859349312] Updating the best model with validation-mAP=0.9923706391292801
# [10/29/2020 04:31:34 INFO 140695859349312] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/29/2020 04:31:34 INFO 140695859349312] #progress_metric: host=algo-1, completed 73 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1603945894.183102, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 10}, "StartTime": 1603945794.315073}
#
# [10/29/2020 04:32:06 INFO 140695859349312] Epoch:    11, batches:    100, num_examples:   1600, 50.0 samples/sec, epoch time so far:  0:00:32.014874
# [10/29/2020 04:32:37 INFO 140695859349312] Epoch:    11, batches:    200, num_examples:   3200, 50.8 samples/sec, epoch time so far:  0:01:03.045280
# [10/29/2020 04:32:44 INFO 140695859349312] #quality_metric: host=algo-1, epoch=11, batch=226 train cross_entropy <loss>=(0.40974790457025734)
# [10/29/2020 04:32:44 INFO 140695859349312] #quality_metric: host=algo-1, epoch=11, batch=226 train smooth_l1 <loss>=(0.17261807195890363)
# [10/29/2020 04:32:44 INFO 140695859349312] Round of batches complete
# [10/29/2020 04:32:45 INFO 140695859349312] Updated the metrics
# [10/29/2020 04:33:10 INFO 140695859349312] #quality_metric: host=algo-1, epoch=11, validation mAP <score>=(0.9909053629088749)
# [10/29/2020 04:33:10 INFO 140695859349312] #progress_metric: host=algo-1, completed 80 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1603945990.920346, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 11}, "StartTime": 1603945894.183428}
#
# [10/29/2020 04:33:43 INFO 140695859349312] Epoch:    12, batches:    100, num_examples:   1600, 49.3 samples/sec, epoch time so far:  0:00:32.462112
# [10/29/2020 04:34:14 INFO 140695859349312] Epoch:    12, batches:    200, num_examples:   3200, 50.5 samples/sec, epoch time so far:  0:01:03.415552
# [10/29/2020 04:34:22 INFO 140695859349312] #quality_metric: host=algo-1, epoch=12, batch=226 train cross_entropy <loss>=(0.3999591068526386)
# [10/29/2020 04:34:22 INFO 140695859349312] #quality_metric: host=algo-1, epoch=12, batch=226 train smooth_l1 <loss>=(0.1646079843681097)
# [10/29/2020 04:34:22 INFO 140695859349312] Round of batches complete
# [10/29/2020 04:34:22 INFO 140695859349312] Updated the metrics
# [10/29/2020 04:34:46 INFO 140695859349312] #quality_metric: host=algo-1, epoch=12, validation mAP <score>=(0.9925576965817204)
# [10/29/2020 04:34:46 INFO 140695859349312] Updating the best model with validation-mAP=0.9925576965817204
# [10/29/2020 04:34:46 INFO 140695859349312] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/29/2020 04:34:46 INFO 140695859349312] #progress_metric: host=algo-1, completed 86 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 13, "sum": 13.0, "min": 13}}, "EndTime": 1603946086.228191, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 12}, "StartTime": 1603945990.920556}
#
# [10/29/2020 04:35:17 INFO 140695859349312] Epoch:    13, batches:    100, num_examples:   1600, 50.4 samples/sec, epoch time so far:  0:00:31.728328
# [10/29/2020 04:35:48 INFO 140695859349312] Epoch:    13, batches:    200, num_examples:   3200, 51.1 samples/sec, epoch time so far:  0:01:02.643604
# [10/29/2020 04:35:56 INFO 140695859349312] #quality_metric: host=algo-1, epoch=13, batch=226 train cross_entropy <loss>=(0.38368043796276735)
# [10/29/2020 04:35:56 INFO 140695859349312] #quality_metric: host=algo-1, epoch=13, batch=226 train smooth_l1 <loss>=(0.15883513935204172)
# [10/29/2020 04:35:56 INFO 140695859349312] Round of batches complete
# [10/29/2020 04:35:56 INFO 140695859349312] Updated the metrics
# [10/29/2020 04:36:19 INFO 140695859349312] #quality_metric: host=algo-1, epoch=13, validation mAP <score>=(0.9950008363386019)
# [10/29/2020 04:36:19 INFO 140695859349312] Updating the best model with validation-mAP=0.9950008363386019
# [10/29/2020 04:36:19 INFO 140695859349312] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/29/2020 04:36:19 INFO 140695859349312] #progress_metric: host=algo-1, completed 93 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1603946179.480688, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 13}, "StartTime": 1603946086.228514}
#
# [10/29/2020 04:36:51 INFO 140695859349312] Epoch:    14, batches:    100, num_examples:   1600, 49.6 samples/sec, epoch time so far:  0:00:32.240918
# [10/29/2020 04:37:22 INFO 140695859349312] Epoch:    14, batches:    200, num_examples:   3200, 50.7 samples/sec, epoch time so far:  0:01:03.098838
# [10/29/2020 04:37:30 INFO 140695859349312] #quality_metric: host=algo-1, epoch=14, batch=226 train cross_entropy <loss>=(0.3744321029404224)
# [10/29/2020 04:37:30 INFO 140695859349312] #quality_metric: host=algo-1, epoch=14, batch=226 train smooth_l1 <loss>=(0.15135753615046899)
# [10/29/2020 04:37:30 INFO 140695859349312] Round of batches complete
# [10/29/2020 04:37:30 INFO 140695859349312] Updated the metrics
# [10/29/2020 04:37:52 INFO 140695859349312] #quality_metric: host=algo-1, epoch=14, validation mAP <score>=(0.99450950403226)
# [10/29/2020 04:37:52 INFO 140695859349312] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1603946272.007612, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 14}, "StartTime": 1603946179.480939}
#
# [10/29/2020 04:37:52 WARNING 140695859349312] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/29/2020 04:37:52 INFO 140695859349312] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/29/2020 04:37:52 INFO 140695859349312] Test data is not provided.
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}, "totaltime": {"count": 1, "max": 1519619.0690994263, "sum": 1519619.0690994263, "min": 1519619.0690994263}, "setuptime": {"count": 1, "max": 10.824918746948242, "sum": 10.824918746948242, "min": 10.824918746948242}}, "EndTime": 1603946272.576312, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1603944753.099278}
#
#
# 2020-10-29 04:38:14 Uploading - Uploading generated training model
# 2020-10-29 04:38:14 Completed - Training job completed
# Training seconds: 1668
# Billable seconds: 1668

# %% [markdown]
# # Deploy Model

# %%
print('\nDeploying model...')
deployed_model = model.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
print('\nModel deployed!')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# Deploying model...
# -----------------!
# Model deployed!

# %% [markdown]
# # Predictions

# %%
image_dir = 'validation'
images = [x for x in os.listdir(image_dir) if x[-3:] == 'jpg']
print(len(images))
# Out:
# 938

# %%
deployed_model.content_type = 'image/jpeg'

# %%
index = 0

image_path = os.path.join(image_dir, images[index])

with open(image_path, 'rb') as f:
    b = bytearray(f.read())

results = deployed_model.predict(b)
results = json.loads(results)

preds = results['prediction']

# %%
preds
# Out:
# [[1.0,
#   0.9616041779518127,
#   0.33674710988998413,
#   0.1259932816028595,
#   0.9623367190361023,
#   0.7773363590240479],
#  [1.0,
#   0.1427660882472992,
#   0.27535873651504517,
#   0.19804063439369202,
#   0.7438811659812927,
#   0.6774674654006958],
#  [1.0,
#   0.0314493253827095,
#   0.3309601843357086,
#   0.34271883964538574,
#   0.8153432607650757,
#   0.9417650699615479],
#  [1.0,
#   0.026857705786824226,
#   0.8804606199264526,
#   0.27037954330444336,
#   0.9587727785110474,
#   0.3994116187095642],
#  [1.0,
#   0.02405819296836853,
#   0.5273309350013733,
#   0.15995626151561737,
#   0.9711759686470032,
#   0.5783132314682007],
#  [1.0,
#   0.02314837835729122,
#   0.8378320932388306,
#   0.24020245671272278,
#   0.9800809621810913,
#   0.4102313220500946],
#  [1.0,
#   0.02312621660530567,
#   0.8849373459815979,
#   0.8337368965148926,
#   0.9546489119529724,
#   0.9638787508010864],
#  [1.0,
#   0.02261609211564064,
#   0.2917948067188263,
#   0.19812744855880737,
#   0.5899863243103027,
#   0.5360580086708069],
#   0.45554956793785095],
#  [1.0,
#   0.010262008756399155,
#   0.04554835706949234,
#   0.16480761766433716,
#   0.17175400257110596,
#   0.2401762306690216],
#  [1.0,
#   0.010260749608278275,
#   0.10506856441497803,
#   0.0818781852722168,
#   0.17741087079048157,
#   0.20568478107452393],
#  [1.0,
#   0.010203445330262184,
#   0.7620311975479126,
#   0.04291308671236038,
#   0.8921382427215576,
#   0.11488380283117294],
#  [1.0,
#   0.010194054804742336,
#   0.07636342942714691,
#   0.571721076965332,
#   0.20512793958187103,
#   0.6457033157348633],
#  [1.0,
#   0.010185020044445992,
#   0.07839429378509521,
#   0.2898487448692322,
#   0.20470136404037476,
#   0.36436980962753296],
#  [1.0,
#   0.010181433521211147,
#   0.10673084110021591,
#   0.22663307189941406,
#   0.2368161976337433,
#   0.30234771966934204],
#  [1.0,
#   0.010177911259233952,
#   0.07484160363674164,
#   0.3932313919067383,
#   0.14550627768039703,
#   0.5203567743301392],
#  [1.0,
#   0.01017257571220398,
#   0.7007529139518738,
#   0.04350681230425835,
#   0.8305986523628235,
#   0.11500319838523865],
#  [1.0,
#   0.010172073729336262,
#   0.43363237380981445,
#   0.061138078570365906,
#   0.5354611277580261,
#   0.16580840945243835],
#  [1.0,
#   0.01015447173267603,
#   0.16989246010780334,
#   0.10280126333236694,
#   0.30002954602241516,
#   0.1780952513217926],
#  [1.0,
#   0.010150502435863018,
#   0.4185536801815033,
#   0.0,
#   0.4883350431919098,
#   0.08719772100448608],
#  [1.0,
#   0.010143235325813293,
#   0.5168078541755676,
#   0.07061882317066193,
#   0.642739474773407,
#   0.14628340303897858],
#  [1.0,
#   0.010141190141439438,
#   0.07837576419115067,
#   0.32136979699134827,
#   0.20590010285377502,
#   0.39548102021217346],
#  [1.0,
#   0.010065469890832901,
#   0.9134462475776672,
#   0.27740323543548584,
#   0.9845332503318787,
#   0.3948761820793152],
#  [1.0,
#   0.010049530304968357,
#   0.13555727899074554,
#   0.08197976648807526,
#   0.20995266735553741,
#   0.20453013479709625],
#  [1.0,
#   0.010038098320364952,
#   0.0,
#   0.5395431518554688,
#   0.07312171161174774,
#   0.612934947013855],
#  [1.0,
#   0.010035902261734009,
#   0.0,
#   0.44584420323371887,
#   0.07409163564443588,
#   0.5192244648933411],
#  [1.0,
#   0.010028863325715065,
#   0.09905866533517838,
#   0.396124005317688,
#   0.24806559085845947,
#   0.5634123682975769]]

# %%
img = Image.open(image_path)
draw = ImageDraw.Draw(img)
font = ImageFont.truetype('/usr/share/fonts/dejavu/DejaVuSansCondensed-Bold.ttf', 25)
w, h =img.size

for pred in preds:
    class_id, score, xmin, ymin, xmax, ymax = pred
    
    if score > 0.7:
        box = [w*xmin, h*ymin, w*xmax, h*ymax]

        draw.rectangle(box, outline='red', width=4)
        draw.text((box[0], box[1]), classes[int(class_id)], font=font)
    else:
        break

plt.xticks([])
plt.yticks([])
plt.imshow(img)
plt.show()

# %%
sagemaker.Session().delete_endpoint(deployed_model.endpoint)
